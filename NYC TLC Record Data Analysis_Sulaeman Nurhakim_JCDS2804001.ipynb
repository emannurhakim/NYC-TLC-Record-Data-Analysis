# %% [markdown]
# # Data Analysis of NYC TLC Trip Record Dataset
#
# > - By Sulaeman Nurhakim | JCDS 2804-001
# > - Purwadhika Digital Technology School | Bootcamp Job Connector Data Science and Machine Learning
# ---

# %% [markdown]
# ## Overview
# ---
# The NYC TLC Trip Record Dataset provides detailed historical data on taxi and for-hire vehicle (FHV) trips in New York City. Released by the New York City Taxi and Limousine Commission (TLC), this dataset includes millions of records covering trips made by yellow taxis, green taxis, and ride-hailing services such as Uber and Lyft.
#
# Each record typically contains information about the pickup and drop-off times and locations, trip distance, fare details, payment type, and other key attributes related to the ride. The dataset spans across all five NYC boroughs—Manhattan, Brooklyn, Queens, The Bronx, and Staten Island—and is updated regularly.
#
# ![NYC Boroughs](https://freetoursbyfoot.com/wp-content/uploads/2022/12/5-boroughs.png)
#
# Due to its rich spatial and temporal information, the dataset is widely used for urban mobility analysis, transportation planning, revenue tracking, and predictive modeling in the context of public and private transportation services.
#
# Source :  https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page

# %% [markdown]
# ## 🧭 Background
# ---
# As one of the most densely populated and dynamic cities in the world, New York City relies heavily on its transportation network to keep people and goods moving efficiently. Among various modes of transport, taxis and for-hire vehicles (FHVs) play a vital role in connecting neighborhoods, supporting tourism, and providing flexible mobility solutions.
#
# To ensure transparency, data-driven policy-making, and public research, the New York City Taxi and Limousine Commission (TLC) publishes detailed trip records from yellow taxis, green taxis, and FHVs such as Uber and Lyft. These datasets contain millions of anonymized trip-level records, including pickup and drop-off times and locations, trip duration, fare amounts, and payment types.
#
# Analyzing this dataset allows us to uncover insights into urban mobility patterns, passenger behavior, peak travel times, and revenue distribution. It also supports initiatives in smart city planning, traffic congestion management, and ride-hailing regulation.
#
# By exploring and visualizing this data, stakeholders can better understand how transportation services operate in NYC and how they evolve over time.

# %% [markdown]
# ## 🧾 Stakeholder Statement – Taxi Companies Perspective
# ---
# As one of the primary service providers in New York City’s transportation ecosystem, taxi companies are directly impacted by the trends, patterns, and insights derived from trip record data.
#
# This analysis provides valuable insights for taxi fleet operators and dispatch companies to:
#
# - Optimize fleet distribution by identifying high-demand pickup zones and peak operating hours.
#
# - Enhance operational efficiency through understanding trip durations, idle times, and distance-based performance.
#
# - Monitor customer behavior and preferences, such as preferred payment methods (cash vs. card) and average trip fares.
#
# - Evaluate revenue trends across different boroughs, days of the week, and hours of the day to support pricing strategies and driver incentives.
#
# The insights gained empower taxi companies to make data-driven decisions that improve service reliability, increase profitability, and enhance rider satisfaction in a highly competitive urban mobility environment.

# %% [markdown]
# ## 🎯 Goal Setting
# ---
#
# The objective of this analysis is to uncover key operational insights from trip, revenue, and payment data in order to:
#
# - Identify spatial and temporal trip patterns across New York City boroughs.
#
# - Analyze tipping behavior and payment type dynamics to improve driver earnings.
#
# - Improve fleet distribution and utilization by reducing demand overconcentration in specific zones.
#
# - Develop actionable strategies to increase efficiency, revenue, and equity in service coverage.
#
# Ultimately, this analysis aims to inform smarter fleet movement, strategic incentives, and rider engagement to create a more balanced, scalable, and driver-friendly ecosystem.

# %% [markdown]
# ## ⚠️ Problem Statement
# ---
# Despite a strong trip volume and centralized performance, several key operational inefficiencies limit overall service optimization:
#
# 1. Zone Congestion & Imbalance:
#     -   A disproportionate concentration of trips in East Harlem and Manhattan leads to overcrowding in some zones while other boroughs like Staten Island and EWR remain underutilized, resulting in inefficient   resource allocation.
#
# 2. Low Tipping Potential in Certain Scenarios:
#     - Tipping is largely driven by credit card usage and shorter trips, while cash payments and longer rides tend to yield little to no tip, affecting driver motivation and earnings consistency.
#
# 3. Limited Multi-Passenger Engagement:
#     - The dominance of solo trips leads to low vehicle occupancy and inefficient ride distribution, especially during high-demand periods.
#
# 4. Underperformance in Outer Boroughs:
#     - Queens, Bronx, and Staten Island show low revenue and trip counts, indicating gaps in service adoption or demand stimulation.
#
# 5. Overreliance on Digital Payment Zones:
#     - While digital payments increase revenue, they are heavily concentrated in high-traffic zones, causing potential tip revenue loss in cash-preferred areas.

# %% [markdown]
# ## Data Understanding
# ---
#
# ## 🗂️ NYC TLC Trip Record – Data Dictionary
#
# | **Column Name**            | **Description**                                                                                      | **Possible Values / Notes**                                        |
# |---------------------------|------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------|
# | `VendorID`                | Code of the LPEP (trip recorder) provider.                                                           | 1 = Creative Mobile Technologies, LLC<br>2 = VeriFone Inc          |
# | `lpep_pickup_datetime`    | Date and time when the taxi meter was turned on (start of trip).                                    | Format: `YYYY-MM-DD HH:MM:SS`                                     |
# | `lpep_dropoff_datetime`   | Date and time when the taxi meter was turned off (end of trip).                                     | Format: `YYYY-MM-DD HH:MM:SS`                                     |
# | `passenger_count`         | Number of passengers (entered by the driver).                                                        | Numeric                                                            |
# | `trip_distance`           | Distance traveled in miles (from the taximeter).                                                     | Numeric                                                            |
# | `PULocationID`            | TLC zone where the trip began (pickup location).                                                     | Integer (location code)                                            |
# | `DOLocationID`            | TLC zone where the trip ended (dropoff location).                                                    | Integer (location code)                                            |
# | `RatecodeID`              | Final rate code used.                                                                                | 1 = Standard rate<br>2 = JFK<br>3 = Newark<br>4 = Nassau/Westchester<br>5 = Negotiated fare<br>6 = Group ride |
# | `store_and_fwd_flag`      | Indicates whether the trip data was stored before being forwarded to the vendor.                     | Y = Yes<br>N = No                                                  |
# | `payment_type`            | Payment method used by the passenger.                                                                | 1 = Credit card<br>2 = Cash<br>3 = No charge<br>4 = Dispute<br>5 = Unknown<br>6 = Voided trip |
# | `fare_amount`             | Fare based on time and distance (from the meter).                                                    | Numeric (USD)                                                      |
# | `extra`                   | Additional charges (e.g., rush hour, overnight).                                                     | Numeric (USD)                                                      |
# | `mta_tax`                 | MTA tax of $0.50 automatically applied.                                                              | Usually 0.5                                                        |
# | `tip_amount`              | Tip amount (credit card tips only).                                                                  | Cash tips are not recorded                                         |
# | `tolls_amount`            | Total tolls paid during the trip.                                                                    | Numeric                                                            |
# | `ehail_fee`               | E-hail fee.                                                                                           | Not available in this dataset                                      |
# | `improvement_surcharge`   | Improvement surcharge ($0.30 per trip).                                                              | Applied since 2015                                                 |
# | `total_amount`            | Total amount charged to the passenger (excluding cash tips).                                         | Numeric (USD)                                                      |
# | `trip_type`               | Type of trip (based on how it was requested).                                                        | 1 = Street-hail<br>2 = Dispatch                                    |
# | `congestion_surcharge`    | Additional congestion surcharge.                                                                     | Usually $2.75                                                      |

# %% [markdown]
# # 1. Data Preparation
# ---

# %%
# importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import missingno as mn
import geopandas as gpd
import scipy
import scipy.stats as stats
from scipy.stats import mannwhitneyu
import os
os.makedirs('output', exist_ok=True)

# %%
# set display columns to 100 for better visibility

pd.options.display.max_columns = 100

# %%
df = pd.read_csv(r"C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\CAPSTONE MODUL 2\Folder Baru\NYC TLC Trip Record.csv")
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\1334158810.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\CAPSTONE MODUL 2\Folder Baru\NYC TLC Trip Record.csv")

# %%
df.head(5)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2         2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3         1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4         1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
# 1         1.0            24            43              1.0           1.81
# 2         1.0           223           179              1.0           0.00
# 3         1.0            41           238              1.0           1.30
# 4         1.0            41            74              1.0           1.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  object
#  2   lpep_dropoff_datetime  68211 non-null  object
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
# ...

# %%
df.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  68211.000000  63887.000000  68211.000000  68211.000000
# mean       1.863028      1.117160     98.549735    138.429901
# std        0.343820      1.372913     61.244314     76.761311
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    219.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     63887.000000   68211.000000  68211.000000  68211.000000
# mean          1.315870       8.114852     16.603545      0.825431
# std           0.979054     585.105955     13.470121      1.269904
# min           0.000000       0.000000    -70.000000     -2.500000
# 25%           1.000000       1.110000      9.300000      0.000000
# ...

# %%
# Change Dataframe Information into Columns and Values

pd.DataFrame({
    'feature': df.columns.values,
    'data_type': df.dtypes.values,
    'null_value(%)': df.isna().mean().values * 100,
    'neg_value(%)': [len(df[col][df[col] < 0]) / len(df) * 100 if col in df.select_dtypes(include=[np.number]).columns else 0 for col in df.columns],
    '0_value(%)': [len(df[col][df[col] == 0]) / len(df) * 100 if col in df.select_dtypes(include=[np.number]).columns else 0 for col in df.columns],
    'duplicate' : df.duplicated().sum(),
    'n_unique': df.nunique().values,
    'sample_unique': [df[col].unique() for col in df.columns]}
).round(3)
# Out:
#                   feature data_type  null_value(%)  neg_value(%)  0_value(%)  \
# 0                VendorID     int64          0.000         0.000       0.000
# 1    lpep_pickup_datetime    object          0.000         0.000       0.000
# 2   lpep_dropoff_datetime    object          0.000         0.000       0.000
# 3      store_and_fwd_flag    object          6.339         0.000       0.000
# 4              RatecodeID   float64          6.339         0.000       0.000
# 5            PULocationID     int64          0.000         0.000       0.000
# 6            DOLocationID     int64          0.000         0.000       0.000
# 7         passenger_count   float64          6.339         0.000       0.493
# 8           trip_distance   float64          0.000         0.000       4.911
# 9             fare_amount   float64          0.000         0.258       0.122
# 10                  extra   float64          0.000         0.117      59.703
# ...

# %% [markdown]
# Before conducting data analysis, it is essential to go through a data cleaning process to ensure that the data used is accurate, consistent, and relevant. Data in need of cleaning would be:
#
# - Duplicates Values
# - Decode Values for Better Visualization
# - Null / Missing Values Data
# - Data Type Correction
# - Outliers and Anomalies Data (including negative values)

# %% [markdown]
# # 2. Data Cleaning
# ---

# %% [markdown]
# ## - Duplicates Values

# %%
# checking for duplicates data

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate data/ rows

# %% [markdown]
# ## - Decode Feature

# %%
vendor_mapping = {
    1: 'Creative Mobile Technologies, LLC',
    2: 'VeriFone Inc'
}
df['VendorID'] = df['VendorID'].map(vendor_mapping)

ratecode_mapping = {
    1: 'Standard rate',
    2: 'JFK',
    3: 'Negotiated fare',
    4: 'Group ride',
    5: 'Other'
}
df['RatecodeID'] = df['RatecodeID'].map(ratecode_mapping)

storefwd_mapping = {
    'Y': 'Store and Forward Trip',
    'N': 'Not Store and Forward Trip'
}
df['store_and_fwd_flag'] = df['store_and_fwd_flag'].map(storefwd_mapping)

payment_mapping = {
    1: 'Credit card',
    2: 'Cash',
    3: 'No charge',
    4: 'Dispute',
    5: 'Unknown',
    6: 'Voided trip'
}
df['payment_type'] = df['payment_type'].map(payment_mapping)

trip_mapping = {
    1: 'Street-hail',
    2: 'Dispatch',
    3: 'Street-hail and Dispatch'
}
df['trip_type'] = df['trip_type'].map(trip_mapping)

df.rename(columns={'VendorID': 'vendor'}, inplace=True)
df.rename(columns={'RatecodeID': 'rate_code'}, inplace=True)
df.rename(columns={'store_and_fwd_flag': 'record_flag'}, inplace=True)

df
# Out:
#                                   vendor lpep_pickup_datetime  \
# 0                           VeriFone Inc  2023-01-01 00:26:10
# 1                           VeriFone Inc  2023-01-01 00:51:03
# 2                           VeriFone Inc  2023-01-01 00:35:12
# 3      Creative Mobile Technologies, LLC  2023-01-01 00:13:14
# 4      Creative Mobile Technologies, LLC  2023-01-01 00:33:04
# ...                                  ...                  ...
# 68206                       VeriFone Inc  2023-01-31 22:29:00
# 68207                       VeriFone Inc  2023-01-31 22:40:00
# 68208                       VeriFone Inc  2023-01-31 23:46:00
# 68209                       VeriFone Inc  2023-01-31 23:01:00
# 68210                       VeriFone Inc  2023-01-31 23:51:00
#
#       lpep_dropoff_datetime                 record_flag      rate_code  \
# 0       2023-01-01 00:37:11  Not Store and Forward Trip  Standard rate
# 1       2023-01-01 00:57:49  Not Store and Forward Trip  Standard rate
# ...

# %% [markdown]
# ## - Null / Missing Values

# %%
# checking for missing values

df.isna().sum()
# Out:
# vendor                       0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# record_flag               4324
# rate_code                 4334
# PULocationID                 0
# DOLocationID                 0
# passenger_count           4324
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                68211
# improvement_surcharge        0
# total_amount                 0
# payment_type              4324
# trip_type                 4334
# congestion_surcharge      4324
# dtype: int64

# %%
# checking for missing values visualization

mn.bar(df, figsize=(15, 5), fontsize=12)
# Out:
# <Axes: >

# %%
mn.heatmap(df, figsize=(15, 5), fontsize=12)
plt.show()

# %% [markdown]
# The correlation matrix visualizes how the missing values in each column are related to each other. Since all the correlations are 1 (perfect positive correlation), it means:
#
# Whenever one column has a missing value, all other columns are also missing in the same row.
# In other words, missingness is perfectly aligned across the columns.

# %% [markdown]
# 4324 total missing values from the column 'store_and_fwd_flag'.

# %% [markdown]
# Assuming the missing values are from the bug within 'store_and_fwd_flag' feature, which supposed to notify the system when no signal are available to update the data, **all missing values will are assumed to be device problem** (data are stored when no signal available, then forward later)

# %%
# missing values percentage based on VendorID

df[df['record_flag'].isna()]['vendor'].value_counts(normalize=True).round(3) * 100
# Out:
# vendor
# VeriFone Inc                         97.0
# Creative Mobile Technologies, LLC     3.0
# Name: proportion, dtype: float64

# %%
# checking for missing values visualization based on VendorID

df['vendor'].value_counts(normalize=True).plot(
    kind='bar',
    color=['#FF9999', '#66B3FF'],
    figsize=(10, 5),
    fontsize=12
)

plt.xticks(rotation=0)
plt.title('Distribution Missing Values based on Vendor')
plt.xlabel('Vendor')
plt.ylabel('Proportion')
plt.tight_layout()
plt.show()

# %% [markdown]
# 97 % of the missing data comes from TSP Vendor: Verifone Inc, while only a small portion is associated with Vendor Creative Mobile Technologies, LLC. Since there are only two vendors in the dataset, this clearly shows that the majority of data quality issues are concentrated in Vendor Verifone Inc. Further investigation or data validation efforts should prioritize this vendor to enhance the overall completeness and reliability of the dataset.

# %%
# checking percentage of missing values

round(df.isna().sum()/len(df)*100,2)
# Out:
# vendor                     0.00
# lpep_pickup_datetime       0.00
# lpep_dropoff_datetime      0.00
# record_flag                6.34
# rate_code                  6.35
# PULocationID               0.00
# DOLocationID               0.00
# passenger_count            6.34
# trip_distance              0.00
# fare_amount                0.00
# extra                      0.00
# mta_tax                    0.00
# tip_amount                 0.00
# tolls_amount               0.00
# ehail_fee                100.00
# improvement_surcharge      0.00
# total_amount               0.00
# payment_type               6.34
# trip_type                  6.35
# congestion_surcharge       6.34
# dtype: float64

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['record_flag',
#  'rate_code',
#  'passenger_count',
#  'ehail_fee',
#  'payment_type',
#  'trip_type',
#  'congestion_surcharge']

# %% [markdown]
# There are 4,324 rows containing missing values in the columns ['RatecodeID', 'passenger_count', 'payment_type', 'congestion_surcharge'], while the column 'trip_type' has 4,334 rows with missing values.

# %% [markdown]
# These missing values account for approximately 6.34% to 6.35% of the total dataset, which is relatively small and does not significantly affect other variables. Therefore, it is reasonable to proceed by dropping the rows containing null values.

# %%
# dropping rows with null values

df.dropna(subset=['record_flag',
 'rate_code',
 'passenger_count',
 'payment_type',
 'trip_type',
 'congestion_surcharge'], inplace=True)

# %%
# checking remaining missing values

df.isna().sum()
# Out:
# vendor                       0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# record_flag                  0
# rate_code                    0
# PULocationID                 0
# DOLocationID                 0
# passenger_count              0
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                63877
# improvement_surcharge        0
# total_amount                 0
# payment_type                 0
# trip_type                    0
# congestion_surcharge         0
# dtype: int64

# %% [markdown]
# The column 'ehail_fee' will be removed from the dataset as it contains 100% null values and does not contribute any meaningful information for the analysis.

# %%
# dropping 'ehail_fee' column

df.drop(columns=['ehail_fee'], inplace=True)

# %%
# verifying all null values have been dropped

df.isna().sum()
# Out:
# vendor                   0
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# record_flag              0
# rate_code                0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# payment_type             0
# trip_type                0
# congestion_surcharge     0
# dtype: int64

# %%
# verifiying missing values visualization

mn.bar(df, figsize=(15, 5), fontsize=12)
# Out:
# <Axes: >

# %% [markdown]
# Summary
# --
# - Decode categorical values in columns: ['VendorID', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'trip_type'] by follow the documentation
#
# - A total of 4,324 rows have missing values in the columns: ['rate_code', 'passenger_count', 'payment_type', 'congestion_surcharge'].
#
# - The column trip_type has 4,334 missing values.
#
# - Missing values represent approximately 6.34% to 6.35% of the total dataset.
#
# - The percentage is relatively small and does not significantly impact other variables.
#
# - Rows with null values will be dropped to ensure data consistency.
#
# - 97% of the missing data comes from TSP Vendor Verifone Inc, while Vendor Creative Mobile Technologies LLC. contributes very little — indicating that data quality issues are concentrated in Vendor Verifone Inc.
#
# - The column 'ehail_fee' will be removed, as it contains 100% null values and provides no meaningful contribution to the analysis.

# %% [markdown]
# ## - Column Data Types

# %%
# converting 'lpep_pickup_datetime' and 'lpep_dropoff_datetime' to datetime format

df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'], format='%Y-%m-%d %H:%M:%S')
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'], format='%Y-%m-%d %H:%M:%S')

# %%
# verifying the conversion

df[['lpep_pickup_datetime','lpep_dropoff_datetime']].dtypes
# Out:
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# dtype: object

# %%
# converting 'passenger_count' to integer type
df['passenger_count'] = df['passenger_count'].astype('Int64')

# %%
# verifying the conversion
df['passenger_count'].dtypes
# Out:
# Int64Dtype()

# %%
# verifying all columns are in the correct format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63877 entries, 0 to 63886
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor                 63877 non-null  object
#  1   lpep_pickup_datetime   63877 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  63877 non-null  datetime64[ns]
#  3   record_flag            63877 non-null  object
#  4   rate_code              63877 non-null  object
#  5   PULocationID           63877 non-null  int64
#  6   DOLocationID           63877 non-null  int64
#  7   passenger_count        63877 non-null  Int64
#  8   trip_distance          63877 non-null  float64
#  9   fare_amount            63877 non-null  float64
#  10  extra                  63877 non-null  float64
#  11  mta_tax                63877 non-null  float64
#  12  tip_amount             63877 non-null  float64
#  13  tolls_amount           63877 non-null  float64
# ...

# %% [markdown]
# ## - Data Anomalies

# %%
# checking data anomalies from descritive statistics
df.describe()
# Out:
#                 lpep_pickup_datetime          lpep_dropoff_datetime  \
# count                          63877                          63877
# mean   2023-01-16 20:29:28.932651776  2023-01-16 20:47:27.346791168
# min              2009-01-01 20:21:27            2009-01-02 11:07:31
# 25%              2023-01-09 12:15:18            2023-01-09 12:33:17
# 50%              2023-01-17 08:44:46            2023-01-17 08:59:19
# 75%              2023-01-24 16:18:41            2023-01-24 16:36:36
# max              2023-02-01 03:10:05            2023-02-01 17:27:05
# std                              NaN                            NaN
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# count  63877.000000  63877.000000          63877.0   63877.000000
# mean      97.730200    138.308797          1.31592       2.576974
# min        1.000000      1.000000              0.0       0.000000
# 25%       74.000000     74.000000              1.0       1.100000
# ...

# %% [markdown]
# From the descriptive statistics, anomalous values were identified in the dataset. Some fare amounts were found to have negative values, which are not logically valid. In addition, potential outliers were observed in the 'trip_distance' and 'fare_amount' columns, indicating unusually high or low values that may require further investigation.

# %%
# checking where fare contains negative values, and store to a variable
negative_values = df[df['total_amount'] < 0]
negative_values
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 662    VeriFone Inc  2023-01-01 14:58:13   2023-01-01 14:58:39
# 898    VeriFone Inc  2023-01-01 17:24:52   2023-01-01 17:25:12
# 1317   VeriFone Inc  2023-01-02 02:05:08   2023-01-02 02:12:57
# 1686   VeriFone Inc  2023-01-02 12:56:53   2023-01-02 13:00:10
# 1864   VeriFone Inc  2023-01-02 13:51:33   2023-01-02 13:52:42
# ...             ...                  ...                   ...
# 63358  VeriFone Inc  2023-01-31 18:39:16   2023-01-31 18:39:29
# 63544  VeriFone Inc  2023-01-31 19:06:18   2023-01-31 19:06:46
# 63655  VeriFone Inc  2023-01-31 20:29:00   2023-01-31 20:29:14
# 63807  VeriFone Inc  2023-01-31 22:44:16   2023-01-31 22:45:18
# 63868  VeriFone Inc  2023-01-31 23:44:44   2023-01-31 23:45:15
#
#                       record_flag      rate_code  PULocationID  DOLocationID  \
# 662    Not Store and Forward Trip  Standard rate            75            74
# ...

# %%
#Checking duplicates based on [lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'] columns

df[df.duplicated(subset=[
    'lpep_pickup_datetime', 
    'lpep_dropoff_datetime', 
    'PULocationID', 
    'DOLocationID'] ,keep=False)]
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 662    VeriFone Inc  2023-01-01 14:58:13   2023-01-01 14:58:39
# 663    VeriFone Inc  2023-01-01 14:58:13   2023-01-01 14:58:39
# 898    VeriFone Inc  2023-01-01 17:24:52   2023-01-01 17:25:12
# 899    VeriFone Inc  2023-01-01 17:24:52   2023-01-01 17:25:12
# 1317   VeriFone Inc  2023-01-02 02:05:08   2023-01-02 02:12:57
# ...             ...                  ...                   ...
# 63656  VeriFone Inc  2023-01-31 20:29:00   2023-01-31 20:29:14
# 63807  VeriFone Inc  2023-01-31 22:44:16   2023-01-31 22:45:18
# 63808  VeriFone Inc  2023-01-31 22:44:16   2023-01-31 22:45:18
# 63868  VeriFone Inc  2023-01-31 23:44:44   2023-01-31 23:45:15
# 63869  VeriFone Inc  2023-01-31 23:44:44   2023-01-31 23:45:15
#
#                       record_flag      rate_code  PULocationID  DOLocationID  \
# 662    Not Store and Forward Trip  Standard rate            75            74
# ...

# %% [markdown]
# The negative fare values were found in duplicate entries based on the columns ['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'], indicating that the anomalies are likely due to duplicated records with inconsistent fare data.

# %%
# Identify duplicate rows based on pickup/dropoff datetime and location combination
duplicate_mask = df.duplicated(subset=['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID'], keep=False)

# Identify rows with negative total_amount values
negative_total_mask = df['total_amount'] < 0

# Combine: duplicates with negative total_amount
dup_and_negative_total = df[duplicate_mask & negative_total_mask]

plt.figure(figsize=(10, 6))
sns.histplot(df[duplicate_mask]['total_amount'], bins=50, kde=True, color='skyblue')
plt.axvline(0, color='red', linestyle='--', label='Zero Amount Line')
plt.title("Distribution of Total Amount in Duplicate Records")
plt.xlabel("Total Amount")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This suggests that many duplicates are exact or nearly identical in terms of transaction amount. These could be due to data entry errors, billing adjustments, or other anomalies. Two types of duplicate record behavior (e.g., some corrected vs. uncorrected transactions).

# %%
dups_with_negative_total = len(dup_and_negative_total)
dups_without_negative_total = len(df[duplicate_mask]) - dups_with_negative_total

plt.figure(figsize=(6, 4))
sns.barplot(x=["Negative Total", "Valid Total"], y=[dups_with_negative_total, dups_without_negative_total], palette="pastel")
plt.title("Duplicate Records: With and Without Negative Total Amount")
plt.ylabel("Number of Records")
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\1031181016.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=["Negative Total", "Valid Total"], y=[dups_with_negative_total, dups_without_negative_total], palette="pastel")

# %% [markdown]
# There is a balanced split between duplicate records with negative and valid total amounts. This indicates that not all duplicates are exact matches — some likely serve as offsets or reversals. because of that, we will drop the duplicate records to clean the data with with negative values

# %%
print("Sample of duplicate records with negative total amount:")
print(dup_and_negative_total[['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID', 'total_amount']].head())
# Out:
# Sample of duplicate records with negative total amount:
#      lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 662   2023-01-01 14:58:13   2023-01-01 14:58:39            75            74
# 898   2023-01-01 17:24:52   2023-01-01 17:25:12           193           193
# 1317  2023-01-02 02:05:08   2023-01-02 02:12:57           129            82
# 1686  2023-01-02 12:56:53   2023-01-02 13:00:10            75            75
# 1864  2023-01-02 13:51:33   2023-01-02 13:52:42            75            75
#
#       total_amount
# 662           -4.5
# 898           -4.5
# 1317         -11.1
# 1686          -5.3
# 1864          -5.2

# %%
# dropping duplicate records with negative total amount
df.drop(negative_values.index, inplace=True)

# %%
# verify on negative fares
df[df['total_amount'] < 0].shape[0]
# Out:
# 0

# %% [markdown]
# Based on common logic and standard vehicle capacity regulations, the number of passengers should be between 1 and 5. A valid trip must have at least one passenger, and the maximum number typically does not exceed five, which aligns with the seating capacity of larger TLC-licensed vehicles such as SUVs or minivans.
#
# (source: https://www.nyc.gov/site/tlc/passengers/passenger-frequently-asked-questions.page)

# %%
# checking passenger_count values < 1 on the dataset

df[df['passenger_count'] < 1]
# Out:
#                                   vendor lpep_pickup_datetime  \
# 99                          VeriFone Inc  2023-01-01 01:27:36
# 254    Creative Mobile Technologies, LLC  2023-01-01 04:21:35
# 446    Creative Mobile Technologies, LLC  2023-01-01 11:42:13
# 486    Creative Mobile Technologies, LLC  2023-01-01 12:11:05
# 487    Creative Mobile Technologies, LLC  2023-01-01 12:56:11
# ...                                  ...                  ...
# 63239  Creative Mobile Technologies, LLC  2023-01-31 18:27:02
# 63247  Creative Mobile Technologies, LLC  2023-01-31 18:01:21
# 63288  Creative Mobile Technologies, LLC  2023-01-31 18:07:39
# 63420  Creative Mobile Technologies, LLC  2023-01-31 18:32:09
# 63421  Creative Mobile Technologies, LLC  2023-01-31 18:36:10
#
#       lpep_dropoff_datetime                 record_flag      rate_code  \
# 99      2023-01-01 01:27:43  Not Store and Forward Trip          Other
# 254     2023-01-01 04:30:00  Not Store and Forward Trip  Standard rate
# ...

# %%
# checking passinger_count values > 5 on the dataset

df[df['passenger_count'] > 5]
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 41     VeriFone Inc  2023-01-01 00:08:05   2023-01-01 00:13:26
# 159    VeriFone Inc  2023-01-01 02:06:14   2023-01-01 02:18:33
# 160    VeriFone Inc  2023-01-01 02:24:20   2023-01-01 02:44:17
# 226    VeriFone Inc  2023-01-01 02:58:07   2023-01-01 03:04:41
# 397    VeriFone Inc  2023-01-01 10:41:13   2023-01-01 10:59:50
# ...             ...                  ...                   ...
# 63491  VeriFone Inc  2023-01-31 19:38:19   2023-01-31 19:45:20
# 63492  VeriFone Inc  2023-01-31 19:58:34   2023-01-31 20:04:32
# 63598  VeriFone Inc  2023-01-31 20:10:10   2023-01-31 20:17:43
# 63599  VeriFone Inc  2023-01-31 20:20:21   2023-01-31 20:43:27
# 63629  VeriFone Inc  2023-01-31 20:31:05   2023-01-31 20:39:53
#
#                       record_flag      rate_code  PULocationID  DOLocationID  \
# 41     Not Store and Forward Trip  Standard rate            41            75
# ...

# %% [markdown]
# Findings =
# - 336 data contains < 1 passenger
# - 1061 data contains > 5 passenger

# %%
# dropping rows with passenger_count < 1
df.drop(df[df['passenger_count'] < 1].index, inplace=True)
# dropping rows with passenger_count > 5
df.drop(df[df['passenger_count'] > 5].index, inplace=True)

# %%
# checking years datetime values

df['lpep_pickup_datetime'].dt.year.value_counts()
# Out:
# lpep_pickup_datetime
# 2023    62303
# 2022        2
# 2009        1
# Name: count, dtype: int64

# %% [markdown]
# There are only three records outside the year 2023. These records do not impact the overall analysis and do not provide any meaningful insights. Therefore, they will be excluded from the dataset.

# %%
# checking rows with year date outside 2023

df[df['lpep_pickup_datetime'].dt.year != 2023]
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 298    VeriFone Inc  2022-12-09 14:10:49   2022-12-09 14:22:26
# 318    VeriFone Inc  2022-12-09 14:55:42   2022-12-09 15:33:06
# 17874  VeriFone Inc  2009-01-01 20:21:27   2009-01-02 11:07:31
#
#                       record_flag      rate_code  PULocationID  DOLocationID  \
# 298    Not Store and Forward Trip  Standard rate             7            56
# 318    Not Store and Forward Trip  Standard rate           260           164
# 17874  Not Store and Forward Trip  Standard rate            65           178
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 298                  1           5.37         16.0    0.0      0.5
# 318                  1           5.48         25.5    0.0      0.5
# 17874                1           7.72         34.5    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# ...

# %%
# located index of rows with year date outside 2023
rows_to_drop = df[df['lpep_pickup_datetime'].dt.year != 2023].index

# %%
# dropping rows with year date outside 2023
df.drop(index=rows_to_drop, inplace=True)

# %% [markdown]
# Summary
# --
# - Cleared **174 rows** containing negative value of trip fares
# - **336** data contains <1 passenger
# - **1061** data contains >5 passenger
# - **3** data are outside year 2023

# %% [markdown]
# # 3. Analyze Outliers
# ---

# %%
# cheching descriptive statistics

df.describe()
# Out:
#                 lpep_pickup_datetime          lpep_dropoff_datetime  \
# count                          62303                          62303
# mean   2023-01-16 22:42:21.999036928  2023-01-16 23:00:29.983837184
# min              2023-01-01 00:01:31            2023-01-01 00:16:02
# 25%              2023-01-09 12:40:22     2023-01-09 12:55:49.500000
# 50%              2023-01-17 08:47:54            2023-01-17 09:03:58
# 75%              2023-01-24 16:26:58            2023-01-24 16:43:33
# max              2023-02-01 03:10:05            2023-02-01 17:27:05
# std                              NaN                            NaN
#
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# count  62303.000000  62303.000000          62303.0   62303.000000
# mean      97.820089    138.394459         1.242701       2.588452
# min        1.000000      1.000000              1.0       0.000000
# 25%       74.000000     74.000000              1.0       1.100000
# ...

# %% [markdown]
# From descriptive statistics, it's likely there are outlier that are heavily skewing the data on 'trip_distance'

# %%
# Plot distribusi trip_distance
plt.figure(figsize=(10, 6))
sns.histplot(df['trip_distance'], bins=100, kde=True, color='skyblue')
plt.title("Distribution of Trip Distance")
plt.xlabel("Trip Distance (miles)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['vendor', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'record_flag', 'rate_code', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# create a list of numerical columns to check for outliers
numerical_columns = ['passenger_count',
                     'trip_distance', 
                     'fare_amount', 
                     'extra', 
                     'mta_tax', 
                     'tip_amount', 
                     'tolls_amount', 
                     'improvement_surcharge', 
                     'total_amount']
#Plotting boxplot for numerical values 
plt.figure(figsize=(15, 15))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(data=df[column], orient='h')
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    
plt.tight_layout()
plt.show()

# %%
# checking trip_distance distribution by boxplot
df.boxplot(column='trip_distance', by='vendor', figsize=(10, 6))
plt.title("Trip Distance by VendorID")
plt.suptitle("")  # Remove the default title
plt.xlabel("VendorID")
plt.ylabel("Trip Distance (miles)")
plt.grid(True)
plt.show()

# %% [markdown]
# From the boxplot, we can found 1 extremely outlier which values are above 200 miles

# %%
# finding rows with trip_distance > 200
outlier_trip_distance = df[df['trip_distance'] > 200]
outlier_trip_distance
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 33373  VeriFone Inc  2023-01-17 18:40:38   2023-01-17 19:04:45
#
#                       record_flag rate_code  PULocationID  DOLocationID  \
# 33373  Not Store and Forward Trip     Other            82           236
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 33373                1        1571.97        29.97    0.0      0.0
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 33373        3.04          6.55                    1.0         43.31
#
#       payment_type    trip_type  congestion_surcharge
# 33373  Credit card  Street-hail                  2.75

# %% [markdown]
# As we can see, it is impossible for a taxi to cover 1,571 miles within 25 minutes. Therefore, the record will be dropped as it is considered invalid.

# %%
# located index of rows with trip_distance > 200
outlier_trip_distance.index
# dropping rows with trip_distance > 200
df.drop(index=outlier_trip_distance.index, inplace=True)

# %%
# verifying trip_distance distribution after dropping outliers by boxplot
df.boxplot(column='trip_distance', by='vendor', figsize=(10, 6))
plt.title("Trip Distance by VendorID")
plt.suptitle("")  # Remove the default title
plt.xlabel("VendorID")
plt.ylabel("Trip Distance (miles)")
plt.grid(True)
plt.show()

# %%
# checking tip_amount distribution by boxplot
df.boxplot(column='tip_amount', by='vendor', figsize=(10, 6))
plt.title("Tip Amount by VendorID")
plt.suptitle("")  # Remove the default title
plt.xlabel("VendorID")
plt.ylabel("Tip Amount")
plt.grid(True)
plt.show()

# %%
# checking tip_amount data anomalies
df[df['tip_amount'] > 200]
# Out:
#              vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 50588  VeriFone Inc  2023-01-25 18:24:30   2023-01-25 18:28:48
#
#                       record_flag      rate_code  PULocationID  DOLocationID  \
# 50588  Not Store and Forward Trip  Standard rate           223           223
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 50588                1           0.76          6.5    2.5      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 50588      222.22           0.0                    1.0        232.72
#
#       payment_type    trip_type  congestion_surcharge
# 50588  Credit card  Street-hail                   0.0

# %%
# reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # 4. Adding Columns and additional Dataset
# ---

# %%
# adding a new column 'trip_duration' by subtracting 'lpep_pickup_datetime' from 'lpep_dropoff_datetime'

df['trip_duration'] = (df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime'])
df['trip_duration']
# Out:
# 0       0 days 00:11:01
# 1       0 days 00:06:46
# 2       0 days 00:06:20
# 3       0 days 00:05:49
# 4       0 days 00:05:58
#               ...
# 62297   0 days 00:07:59
# 62298   0 days 00:10:45
# 62299   0 days 00:06:01
# 62300   0 days 00:09:32
# 62301   0 days 00:09:56
# Name: trip_duration, Length: 62302, dtype: timedelta64[ns]

# %%
# Adding Day Name Columns

df['pickup_day']=df['lpep_pickup_datetime'].dt.day_name()
df['dropoff_day']=df['lpep_dropoff_datetime'].dt.day_name()
df['pickup_day_no']=df['lpep_pickup_datetime'].dt.weekday
df['dropoff_day_no']=df['lpep_dropoff_datetime'].dt.weekday
df['pickup_hour']=df['lpep_pickup_datetime'].dt.hour
df['dropoff_hour']=df['lpep_dropoff_datetime'].dt.hour
df['pickup_month']=df['lpep_pickup_datetime'].dt.month
df['dropoff_month']=df['lpep_dropoff_datetime'].dt.month

# %%
# adding tips percentage column 

df['tip_percentage'] = (df['tip_amount'] / df['fare_amount']) * 100

# %%
df.head(5)
# Out:
#                               vendor lpep_pickup_datetime  \
# 0                       VeriFone Inc  2023-01-01 00:26:10
# 1                       VeriFone Inc  2023-01-01 00:51:03
# 2                       VeriFone Inc  2023-01-01 00:35:12
# 3  Creative Mobile Technologies, LLC  2023-01-01 00:13:14
# 4  Creative Mobile Technologies, LLC  2023-01-01 00:33:04
#
#   lpep_dropoff_datetime                 record_flag      rate_code  \
# 0   2023-01-01 00:37:11  Not Store and Forward Trip  Standard rate
# 1   2023-01-01 00:57:49  Not Store and Forward Trip  Standard rate
# 2   2023-01-01 00:41:32  Not Store and Forward Trip  Standard rate
# 3   2023-01-01 00:19:03  Not Store and Forward Trip  Standard rate
# 4   2023-01-01 00:39:02  Not Store and Forward Trip  Standard rate
#
#    PULocationID  DOLocationID  passenger_count  trip_distance  fare_amount  \
# 0           166           143                1           2.58         14.9
# ...

# %% [markdown]
# ## - Additional Dataset
#
# ### 1. Taxi Zone Dataset
#
# • The pick-up and drop-off locations are populated by numbers ranging from 1 to 263. These numbers corresponds to taxi zone.
#
# • Taxi Zone Look Up Table: a table that contains a list of TLC taxi zone location IDs, location names, and corresponding boroughs of each zone.
#
# Obtained from: https://www.nyc.gov/assets/tlc/downloads/pdf/trip_record_user_guide.pdf

# %%
# loading taxi zone lookup table
df_zone = pd.read_csv(r"C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\CAPSTONE MODUL 2\Data Web Nyc Tlc\taxi_zone_lookup.csv")
df_zone
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
# join 'PickUpLocation'
df = df.merge(df_zone[['Borough', 'Zone']], left_on='PULocationID', right_on=df_zone['LocationID'], how='inner')

# renaming columns
df.rename(columns={'Borough': 'PickUpBorough','Zone': 'PickUpZone'}, inplace=True)

# %%
# join 'DropOffLocation'
df = df.merge(df_zone[['Borough', 'Zone']], left_on='DOLocationID', right_on=df_zone['LocationID'], how='inner')

# renaming columns
df.rename(columns={'Borough': 'DropOffBorough','Zone': 'DropOffZone'}, inplace=True)

# %%
df.columns
# Out:
# Index(['vendor', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'record_flag', 'rate_code', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type', 'congestion_surcharge', 'trip_duration',
#        'pickup_day', 'dropoff_day', 'pickup_day_no', 'dropoff_day_no',
#        'pickup_hour', 'dropoff_hour', 'pickup_month', 'dropoff_month',
#        'tip_percentage', 'PickUpBorough', 'PickUpZone', 'DropOffBorough',
#        'DropOffZone'],
#       dtype='object')

# %%
# rearange columns so new columns are next to PULocationID
df = df [['vendor', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
       'record_flag', 'rate_code', 'PULocationID', 'PickUpBorough', 'PickUpZone',
       'DOLocationID', 'DropOffBorough', 'DropOffZone',
       'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
       'payment_type', 'trip_type', 'congestion_surcharge', 'trip_duration',
       'pickup_day', 'dropoff_day', 'pickup_day_no', 'dropoff_day_no',
       'pickup_hour', 'dropoff_hour', 'pickup_month', 'dropoff_month',
       'tip_percentage']]

# %%
df.columns
# Out:
# Index(['vendor', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'record_flag', 'rate_code', 'PULocationID', 'PickUpBorough',
#        'PickUpZone', 'DOLocationID', 'DropOffBorough', 'DropOffZone',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type', 'congestion_surcharge', 'trip_duration',
#        'pickup_day', 'dropoff_day', 'pickup_day_no', 'dropoff_day_no',
#        'pickup_hour', 'dropoff_hour', 'pickup_month', 'dropoff_month',
#        'tip_percentage'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                               vendor lpep_pickup_datetime  \
# 0                       VeriFone Inc  2023-01-01 00:26:10
# 1                       VeriFone Inc  2023-01-01 00:51:03
# 2                       VeriFone Inc  2023-01-01 00:35:12
# 3  Creative Mobile Technologies, LLC  2023-01-01 00:13:14
# 4  Creative Mobile Technologies, LLC  2023-01-01 00:33:04
#
#   lpep_dropoff_datetime                 record_flag      rate_code  \
# 0   2023-01-01 00:37:11  Not Store and Forward Trip  Standard rate
# 1   2023-01-01 00:57:49  Not Store and Forward Trip  Standard rate
# 2   2023-01-01 00:41:32  Not Store and Forward Trip  Standard rate
# 3   2023-01-01 00:19:03  Not Store and Forward Trip  Standard rate
# 4   2023-01-01 00:39:02  Not Store and Forward Trip  Standard rate
#
#    PULocationID PickUpBorough           PickUpZone  DOLocationID  \
# 0           166     Manhattan  Morningside Heights           143
# 1            24     Manhattan         Bloomingdale            43
# ...

# %%
df['Date'] = df['lpep_dropoff_datetime'].dt.date

# %%
df.head(5)
# Out:
#                               vendor lpep_pickup_datetime  \
# 0                       VeriFone Inc  2023-01-01 00:26:10
# 1                       VeriFone Inc  2023-01-01 00:51:03
# 2                       VeriFone Inc  2023-01-01 00:35:12
# 3  Creative Mobile Technologies, LLC  2023-01-01 00:13:14
# 4  Creative Mobile Technologies, LLC  2023-01-01 00:33:04
#
#   lpep_dropoff_datetime                 record_flag      rate_code  \
# 0   2023-01-01 00:37:11  Not Store and Forward Trip  Standard rate
# 1   2023-01-01 00:57:49  Not Store and Forward Trip  Standard rate
# 2   2023-01-01 00:41:32  Not Store and Forward Trip  Standard rate
# 3   2023-01-01 00:19:03  Not Store and Forward Trip  Standard rate
# 4   2023-01-01 00:39:02  Not Store and Forward Trip  Standard rate
#
#    PULocationID PickUpBorough           PickUpZone  DOLocationID  \
# 0           166     Manhattan  Morningside Heights           143
# 1            24     Manhattan         Bloomingdale            43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62302 entries, 0 to 62301
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor                 62302 non-null  object
#  1   lpep_pickup_datetime   62302 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62302 non-null  datetime64[ns]
#  3   record_flag            62302 non-null  object
#  4   rate_code              62302 non-null  object
#  5   PULocationID           62302 non-null  int64
#  6   PickUpBorough          62238 non-null  object
#  7   PickUpZone             62173 non-null  object
#  8   DOLocationID           62302 non-null  int64
#  9   DropOffBorough         62082 non-null  object
#  10  DropOffZone            61899 non-null  object
#  11  passenger_count        62302 non-null  Int64
#  12  trip_distance          62302 non-null  float64
#  13  fare_amount            62302 non-null  float64
# ...

# %% [markdown]
# # 5. Data Analysis
# ---

# %% [markdown]
# ## - Time Scope Period

# %%
# time period from data

df[['lpep_pickup_datetime', 'lpep_dropoff_datetime']].agg(['max', 'min'])
# Out:
#     lpep_pickup_datetime lpep_dropoff_datetime
# max  2023-02-01 03:10:05   2023-02-01 17:27:05
# min  2023-01-01 00:01:31   2023-01-01 00:16:02

# %% [markdown]
# The Data available are within 1 month period of **January 1st 2023 - February 2nd 2023**

# %% [markdown]
# ## - Number of trips per date

# %%
# Lalu hitung jumlah dropoff per tanggal
count_per_day = df.groupby('Date').size().reset_index(name='count')

# Sort berdasarkan tanggal
count_per_day = count_per_day.sort_values('Date')

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Date', y='count', data=count_per_day)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# insight:
# - There's a recurring wave-like pattern in the count — some days drop below 1500 and others peak above 2300.
#
# - This might reflect a weekday vs. weekend pattern, operational cycles, or user behavior.

# %% [markdown]
# ## - Number of trips per day and Revenue

# %%
# --- Hitung jumlah trip per hari ---
trips_per_day = df.groupby(['dropoff_day_no', 'dropoff_day']).size().reset_index(name='count')
trips_per_day = trips_per_day.sort_values('dropoff_day_no')

# --- Hitung total revenue per hari ---
revenue_per_day = df.groupby(['dropoff_day_no', 'dropoff_day'])['total_amount'].sum().reset_index()
revenue_per_day = revenue_per_day.sort_values('dropoff_day_no')

# --- Gabungkan kedua grafik dalam 1 figure ---
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# --- Grafik 1: Jumlah trip per hari ---
sns.barplot(ax=axes[0], data=trips_per_day, x='dropoff_day', y='count', palette='viridis')
sns.lineplot(ax=axes[0], data=trips_per_day, x='dropoff_day', y='count', color='black', marker='o', linewidth=2)

# Tambahkan label angka di atas batang
for i, row in trips_per_day.iterrows():
    axes[0].text(x=i,
                 y=row['count'] + 100,
                 s=f"{row['count']:,}",
                 ha='center', va='bottom', fontsize=9)

axes[0].set_title('Number of Trips per Day (Monday–Sunday)')
axes[0].set_xlabel('Days')
axes[0].set_ylabel('Number of Trips')

# --- Grafik 2: Total revenue per hari ---
sns.barplot(ax=axes[1], data=revenue_per_day, x='dropoff_day', y='total_amount', palette='magma')

# Tambahkan label angka di atas batang
for i, row in revenue_per_day.iterrows():
    axes[1].text(x=i,
                 y=row['total_amount'] + 100,
                 s=f"${row['total_amount']:,.0f}",
                 ha='center', va='bottom', fontsize=9)

axes[1].set_title('Total Revenue per Day (Monday–Sunday)')
axes[1].set_xlabel('Days')
axes[1].set_ylabel('Total Revenue (USD)')

# --- Finalisasi ---
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\3822133681.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[0], data=trips_per_day, x='dropoff_day', y='count', palette='viridis')
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\3822133681.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[1], data=revenue_per_day, x='dropoff_day', y='total_amount', palette='magma')

# %% [markdown]
# Insight:
#
# - Weekdays are busier: Both in terms of trip volume and revenue generation.
#
# - Tuesday is the peak day: Highest demand and earnings.
#
# - Weekends are less active: Fewer trips and lower total revenue — possibly due to reduced commuting or business travel.

# %% [markdown]
# ## - Rate Code and Revenue

# %%
rate_counts = df['rate_code'].value_counts()
print(rate_counts)

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='rate_code', order=rate_counts.index)
plt.title("Distribusi Rate Code")
plt.xlabel("Rate Code")
plt.ylabel("Jumlah Perjalanan")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# rate_code
# Standard rate      60576
# Other               1485
# JFK                  154
# Group ride            57
# Negotiated fare       30
# Name: count, dtype: int64

# %%
# Rata-rata total_amount per rate_code
avg_total_by_rate = df.groupby('rate_code')['total_amount'].mean().reset_index()
print(avg_total_by_rate)

plt.figure(figsize=(8, 5))
sns.barplot(data=avg_total_by_rate, x='rate_code', y='total_amount')
plt.title("Rata-rata Total Amount per Rate Code")
plt.xlabel("Rate Code")
plt.ylabel("Rata-rata Total Amount ($)")
plt.tight_layout()
plt.show()
# Out:
#          rate_code  total_amount
# 0       Group ride    103.621754
# 1              JFK     84.995325
# 2  Negotiated fare     76.973333
# 3            Other     33.452909
# 4    Standard rate     20.752595

# %%
# Total revenue per rate_code
revenue_total = df.groupby('rate_code')['total_amount'].sum().reset_index().sort_values(by='total_amount', ascending=False)

# Average revenue per trip
revenue_avg = df.groupby('rate_code')['total_amount'].mean().reset_index().sort_values(by='total_amount', ascending=False)

# Total Revenue
plt.figure(figsize=(8, 5))
sns.barplot(data=revenue_total, x='rate_code', y='total_amount')
plt.title("Total Revenue per Rate Code")
plt.xlabel("Rate Code")
plt.ylabel("Total Revenue ($)")
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('${x:,.0f}'))  # Format angka besar
plt.tight_layout()
plt.grid(True)
plt.show()

# Rata-rata Revenue per Trip
plt.figure(figsize=(8, 5))
sns.barplot(data=revenue_avg, x='rate_code', y='total_amount')
plt.title("Average Revenue per Trip per Rate Code")
plt.xlabel("Rate Code")
plt.ylabel("Average Revenue per Trip ($)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
# Data revenue per rate_code
revenue_total = df.groupby('rate_code')['total_amount'].sum()
labels = revenue_total.index
sizes = revenue_total.values

# Warna custom (opsional)
colors = sns.color_palette('Set3', len(labels))

# Explode bagian pertama sedikit (Standard rate)
explode = [0.05 if i == 0 else 0 for i in range(len(labels))]

# Buat pie chart
plt.figure(figsize=(10, 10))
plt.pie(
    sizes, 
    labels=labels, 
    autopct='%1.1f%%',
    startangle=140, 
    colors=colors, 
    explode=explode, 
    shadow=True, 
    textprops={'fontsize': 12}
)
plt.title("Revenue Proportion Based on Rate Code", fontsize=16)
plt.axis('equal')  # Lingkaran sempurna
plt.tight_layout()
plt.show()

# %% [markdown]
# - The Standard rate brings in the most total revenue because it has very high volume, but each trip is low in value.
#
# - Conversely, Group ride, JFK, and Negotiated fare have fewer trips, but each trip is high value.

# %%
# Group by rate_code dan trip_type_label
cross_tab = df.groupby(['rate_code', 'trip_type']).size().reset_index(name='count')

# Pivot table
pivot_table = cross_tab.pivot(index='rate_code', columns='trip_type', values='count').fillna(0)

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Sum of Trips Based on Rate Code and Trip Type")
plt.xlabel("Trip Type")
plt.ylabel("Rate Code")
plt.tight_layout()
plt.show()

# %% [markdown]
# - 60,570 trips came from Standard rate via Street-hail — this is the overwhelming majority of all trips.
#
# - Only 6 Standard rate trips came from Dispatch — so almost all Standard trips are hailed on the street.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62302 entries, 0 to 62301
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor                 62302 non-null  object
#  1   lpep_pickup_datetime   62302 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62302 non-null  datetime64[ns]
#  3   record_flag            62302 non-null  object
#  4   rate_code              62302 non-null  object
#  5   PULocationID           62302 non-null  int64
#  6   PickUpBorough          62238 non-null  object
#  7   PickUpZone             62173 non-null  object
#  8   DOLocationID           62302 non-null  int64
#  9   DropOffBorough         62082 non-null  object
#  10  DropOffZone            61899 non-null  object
#  11  passenger_count        62302 non-null  Int64
#  12  trip_distance          62302 non-null  float64
#  13  fare_amount            62302 non-null  float64
# ...

# %% [markdown]
# ## - Trip Duration over Distance

# %%
# Hitung durasi dalam menit
df['trip_duration_minutes'] = df['trip_duration'].dt.total_seconds() / 60

# Filter durasi yang masuk akal (< 60 menit)
filtered_df = df[df['trip_duration_minutes'] < 1500]

# Visualisasi setelah filtering
plt.figure(figsize=(10, 6))
sns.histplot(filtered_df['trip_duration_minutes'], bins=40, kde=True)
plt.title("Trip Duration Distribution")
plt.xlabel("Trip Duration (minutes)")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fokus hanya pada perjalanan < 10 mil
filtered_df = df[df['trip_distance'] < 100]

plt.figure(figsize=(10, 6))
sns.histplot(filtered_df['trip_distance'], bins=40, kde=True)
plt.title("Trip Distance Distribution")
plt.xlabel("Trip Distance (miles)")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter outlier ekstrem
filtered_df = df[(df['trip_distance']<100) & (df['trip_duration_minutes']<2000)]

# Buat plot
plt.figure(figsize=(10, 6))

# Scatterplot
sns.scatterplot(
    data=filtered_df,
    x='trip_distance',
    y='trip_duration_minutes',
    alpha=0.5
)

# Tambahkan garis regresi merah
sns.regplot(
    data=filtered_df,
    x='trip_distance',
    y='trip_duration_minutes',
    scatter=False,   # supaya tidak menggambar ulang scatter-nya
    color='red',
    line_kws={'linewidth': 2}
)

# Label dan tampilan
plt.title("Scatterplot Distance vs Trip Duration With Regression Line")
plt.xlabel("Trip Distance (miles)")
plt.ylabel("Trip Duration (minutes)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter data seperti sebelumnya
filtered_df = df[(df['trip_distance']< 30) & (df['trip_duration_minutes']<200)]

# Hitung korelasi Pearson
correlation = filtered_df['trip_distance'].corr(filtered_df['trip_duration_minutes'])

print(f"Coefficient Pearson Correlation: {correlation:.3f}")
# Out:
# Coefficient Pearson Correlation: 0.658

# %% [markdown]
# - Distance and duration are positively related, but not tightly — probably due to varied traffic, wait times, or data noise.
#
# - There are significant outliers with unusually long durations for short trips, which may need further investigation or cleaning.
#
# - The regression line helps quantify the trend, but real-world factors (traffic, stop time, etc.) introduce a lot of variability.

# %% [markdown]
# ## - Time Management

# %%
# Hitung jumlah trip per pickup hour
trips_per_hour = df.groupby('pickup_hour').size().reset_index(name='count')
trips_per_hour = trips_per_hour.sort_values('pickup_hour')

# Plot
plt.figure(figsize=(12, 6))

# Barplot dengan label (jika kamu tetap ingin legend untuk barplot, bisa diberi label di sini)
sns.barplot(data=trips_per_hour, x='pickup_hour', y='count', palette='crest')

# Trendline tanpa label (tidak muncul di legend)
sns.lineplot(data=trips_per_hour, x='pickup_hour', y='count', color='black', marker='o', linewidth=2)

# Label angka di atas bar
for i, row in trips_per_hour.iterrows():
    plt.text(x=i, 
             y=row['count'] + 100, 
             s=f"{row['count']:,}", 
             ha='center', 
             va='bottom', 
             fontsize=9)

# Finalisasi tampilan
plt.title('Trip Over Hours (Pickup Hour) with Trendline')
plt.xlabel('Pickup Hours (0–23)')
plt.ylabel('Sum of Trips')
plt.xticks(range(24))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\3092532785.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=trips_per_hour, x='pickup_hour', y='count', palette='crest')

# %% [markdown]
# - Trip demand is lowest in the early morning, peaks sharply in the late afternoon, and tapers off by late evening.
#
# - This trend is consistent with typical urban mobility patterns — morning rise, afternoon peak, and night decline.
#
# - Businesses can optimize driver availability and target promos or incentives during peak and off-peak hours accordingly.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62302 entries, 0 to 62301
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor                 62302 non-null  object
#  1   lpep_pickup_datetime   62302 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62302 non-null  datetime64[ns]
#  3   record_flag            62302 non-null  object
#  4   rate_code              62302 non-null  object
#  5   PULocationID           62302 non-null  int64
#  6   PickUpBorough          62238 non-null  object
#  7   PickUpZone             62173 non-null  object
#  8   DOLocationID           62302 non-null  int64
#  9   DropOffBorough         62082 non-null  object
#  10  DropOffZone            61899 non-null  object
#  11  passenger_count        62302 non-null  Int64
#  12  trip_distance          62302 non-null  float64
#  13  fare_amount            62302 non-null  float64
# ...

# %%
# Tambahkan kolom untuk weekday/weekend
df['day_type'] = df['pickup_day_no'].apply(lambda x: 'Weekday' if x < 5 else 'Weekend')

hourly_trips_split = df.groupby(['day_type', 'pickup_hour']).size().reset_index(name='trip_count')

plt.figure(figsize=(12, 6))
sns.lineplot(data=hourly_trips_split, x='pickup_hour', y='trip_count', hue='day_type', marker='o')

plt.title('Peak Hour: Perbandingan Weekday vs Weekend')
plt.xlabel('Jam Penjemputan')
plt.ylabel('Jumlah Perjalanan')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
revenue_per_hour = df.groupby(['day_type', 'pickup_hour'])['total_amount'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=revenue_per_hour, x='pickup_hour', y='total_amount', hue='day_type', marker='o')

plt.title('Total Revenue per Hour: Weekday vs Weekend')
plt.xlabel('Jam Penjemputan')
plt.ylabel('Total Revenue (USD)')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
heatmap_data = df.groupby(['pickup_day', 'pickup_hour']).size().reset_index(name='trip_count')

# Ubah ke format matriks
heatmap_pivot = heatmap_data.pivot(index='pickup_day', columns='pickup_hour', values='trip_count')

# Urutkan hari agar mulai dari Senin
ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
heatmap_pivot = heatmap_pivot.reindex(ordered_days)

plt.figure(figsize=(16, 6))
sns.heatmap(heatmap_pivot, cmap='YlOrRd', linewidths=0.5, annot=True, fmt='g')

plt.title('Heatmap Jumlah Perjalanan per Hari dan Jam')
plt.xlabel('Jam Penjemputan')
plt.ylabel('Hari')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Tuesday to Friday afternoons (15:00–18:00) are the busiest hours of the week.
#
# - Weekend trips are more spread out, with higher activity early in the morning than weekdays.
#
# - The heatmap confirms a strong link between trip demand and daily human activity cycles (commuting, leisure, night out).
#
# - This data can inform driver scheduling, pricing strategy, and maintenance planning.

# %% [markdown]
# ## - Tip Amount vs Duration and Distance

# %%
filtered_df = df[
    (df['trip_distance'] > 0) & (df['trip_distance'] < 30) &
    (df['trip_duration_minutes'] > 0) & (df['trip_duration_minutes'] < 200) &
    (df['tip_amount'] >= 0)
]

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=filtered_df,
    x='trip_distance',
    y='tip_amount',
    alpha=0.4
)
sns.regplot(
    data=filtered_df,
    x='trip_distance',
    y='tip_amount',
    scatter=False,
    color='red',
    line_kws={'label': 'Trend'}
)
plt.title('Tip Amount vs Trip Distance')
plt.xlabel('Jarak Perjalanan (mil)')
plt.ylabel('Tip (USD)')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=filtered_df,
    x='trip_duration_minutes',
    y='tip_amount',
    alpha=0.4
)
sns.regplot(
    data=filtered_df,
    x='trip_duration_minutes',
    y='tip_amount',
    scatter=False,
    color='red',
    line_kws={'label': 'Trend'}
)
plt.title('Tip Amount vs Trip Duration')
plt.xlabel('Durasi Perjalanan (menit)')
plt.ylabel('Tip (USD)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\4013726441.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\4013726441.py:47: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# - The red regression line shows a slight upward trend, meaning that longer trips generally receive slightly higher tips.
#
# - However, the increase is marginal, indicating a weak correlation between distance and tip amount. also, Longer trips might yield slightly higher tips, but the trend is minimal.

# %%
dist_corr = filtered_df['trip_distance'].corr(filtered_df['tip_amount'])
dur_corr = filtered_df['trip_duration_minutes'].corr(filtered_df['tip_amount'])

print(f"Korelasi tip vs jarak: {dist_corr:.3f}")
print(f"Korelasi tip vs durasi: {dur_corr:.3f}")
# Out:
# Korelasi tip vs jarak: 0.350
# Korelasi tip vs durasi: 0.282

# %%
filtered_df = df[(df['tip_percentage'] >= 0) & (df['tip_percentage'] <= 100)]

plt.figure(figsize=(10, 5))
sns.histplot(filtered_df['tip_percentage'], bins=50, kde=True, color='teal')
plt.title('Distribusi Tip Percentage')
plt.xlabel('Tip (%) dari Total Amount')
plt.ylabel('Jumlah Perjalanan')
plt.tight_layout()
plt.show()

# %%
df.groupby('payment_type')['tip_percentage'].mean().sort_values(ascending=False)

# Buat kelompok jarak
filtered_df['distance_bucket'] = pd.cut(filtered_df['trip_distance'], bins=[0, 2, 5, 10, 20], labels=['<2mi', '2–5mi', '5–10mi', '10–20mi'])

# Plot rata-rata tip% per kelompok jarak
plt.figure(figsize=(8, 5))
sns.barplot(data=filtered_df, x='distance_bucket', y='tip_percentage', estimator='mean', palette='viridis')
plt.title('Rata-rata Tip Percentage Berdasarkan Jarak')
plt.xlabel('Kelompok Jarak')
plt.ylabel('Rata-rata Tip (%)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\2072533909.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['distance_bucket'] = pd.cut(filtered_df['trip_distance'], bins=[0, 2, 5, 10, 20], labels=['<2mi', '2–5mi', '5–10mi', '10–20mi'])
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\2072533909.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=filtered_df, x='distance_bucket', y='tip_percentage', estimator='mean', palette='viridis')

# %%
tip_by_payment = filtered_df.groupby('payment_type')['tip_percentage'].mean().reset_index().sort_values(by='tip_percentage', ascending=False)
print(tip_by_payment)
plt.figure(figsize=(8, 5))
sns.barplot(data=tip_by_payment, x='payment_type', y='tip_percentage', palette='pastel')

plt.title('Rata-rata Tip Percentage Berdasarkan Payment Type')
plt.xlabel('Payment Type')
plt.ylabel('Rata-rata Tip (%)')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
#   payment_type  tip_percentage
# 1  Credit card       20.879304
# 3    No charge        0.484645
# 0         Cash        0.001446
# 2      Dispute        0.000000
# 4      Unknown        0.000000
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\1354387561.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tip_by_payment, x='payment_type', y='tip_percentage', palette='pastel')

# %% [markdown]
# - Tipping is often low or non-existent, but when given, it's commonly around 20–25%, likely influenced by app defaults.
#
# - Short trips receive higher tip percentages than longer ones.
#
# - Tipping is strongly linked to credit card usage — other payment methods rarely result in tips.

# %% [markdown]
# ## - Passenger Behaviour

# %% [markdown]
# ### Trips count over number of passenger

# %%
# Hitung jumlah trip per jumlah penumpang
trips_by_passenger = df.groupby('passenger_count').size().reset_index(name='count')
trips_by_passenger = trips_by_passenger.sort_values('passenger_count')

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=trips_by_passenger, x='passenger_count', y='count', palette='viridis')

# Tambahkan label angka di atas bar
for i, row in trips_by_passenger.iterrows():
    plt.text(x=i, 
             y=row['count'] + 100, 
             s=f"{row['count']:,}", 
             ha='center', 
             va='bottom',
             fontsize=9)

# Finalisasi
plt.title('Jumlah Trip berdasarkan Jumlah Penumpang')
plt.xlabel('Jumlah Penumpang')
plt.ylabel('Jumlah Trip')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\2484256923.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=trips_by_passenger, x='passenger_count', y='count', palette='viridis')

# %% [markdown]
# The majority of trips involve a single passenger, indicating that services are primarily being used for individual transport, rather than group rides.

# %%
print(df['payment_type'].unique())
# Out:
# ['Credit card' 'Cash' 'No charge' 'Dispute' 'Unknown']

# %%
# Hitung jumlah trip per payment type
trips_by_payment = df['payment_type'].value_counts().reset_index()
trips_by_payment.columns = ['payment_type', 'count']

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=trips_by_payment, x='payment_type', y='count', palette='rocket')

# Tambahkan angka di atas batang
for i, row in trips_by_payment.iterrows():
    plt.text(x=i, 
             y=row['count'] + 100, 
             s=f"{row['count']:,}", 
             ha='center', 
             va='bottom',
             fontsize=9)

# Finalisasi
plt.title('Jumlah Trip berdasarkan Jenis Pembayaran')
plt.xlabel('Jenis Pembayaran')
plt.ylabel('Jumlah Trip')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\723550865.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=trips_by_payment, x='payment_type', y='count', palette='rocket')

# %% [markdown]
# While credit cards are the most popular payment method, cash is still used in a substantial portion of trips. Other methods like "No charge" and "Dispute" are rare and may represent edge cases or anomalies.

# %%
payment_borough = df.groupby(['PickUpBorough', 'payment_type']).size().reset_index(name='count')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=payment_borough, 
            x='PickUpBorough', 
            y='count', 
            hue='payment_type', 
            palette='Set2')

plt.title('Distribusi Payment Type per PickUp Borough')
plt.xlabel('Borough')
plt.ylabel('Jumlah Trip')
plt.legend(title='Payment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
revenue_borough = df.groupby('PickUpBorough')['total_amount'].sum().reset_index()
revenue_borough = revenue_borough.sort_values('total_amount', ascending=False)

# Plot bar
plt.figure(figsize=(14, 10))
ax = sns.barplot(data=revenue_borough, x='PickUpBorough', y='total_amount', palette='flare')

# Tambahkan label angka langsung di atas bar yang sesuai
for bar in ax.patches:
    x = bar.get_x() + bar.get_width() / 2  # posisi tengah bar
    y = bar.get_height()  # tinggi bar (nilai total_amount)
    label = f"${y:,.0f}"  # format label
    ax.text(x, y + 1000, label, ha='center', va='bottom', fontsize=14)

# Judul dan label
plt.title('Total Revenue per PickUp Borough')
plt.xlabel('PickUp Borough')
plt.ylabel('Total Revenue (USD)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sulae\AppData\Local\Temp\ipykernel_50972\854746697.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=revenue_borough, x='PickUpBorough', y='total_amount', palette='flare')

# %% [markdown]
# - Manhattan dominates in both trip volume and revenue, largely driven by credit card payments, which are associated with higher average fares and tipping.
#
# - Brooklyn and Queens are secondary hubs, with more balanced payment types, suggesting mixed customer behavior (possibly more locals).
#
# - Credit card usage correlates with higher revenue, reinforcing earlier insights that digital payments play a crucial role in monetization.
#
# - Other boroughs have minimal contribution, suggesting limited service reach or low demand in those areas.

# %%
#Descriptive stats of total fares in PickUp Borough

df.groupby(df['PickUpBorough'])['total_amount'].agg(['median','min','max','sum'])
# Out:
#                median    min     max        sum
# PickUpBorough
# Bronx           19.00    0.0   97.28   20836.79
# Brooklyn        20.88    0.0  426.00  202440.06
# EWR            200.00  200.0  200.00     200.00
# Manhattan       17.10    0.0  201.00  729797.42
# Queens          17.00    0.0  491.00  368207.47
# Staten Island   29.60   11.2  110.25     432.90
# Unknown         15.50    0.0   83.20    2353.38

# %%
# Descriptive stats of total fares in DropOff Borough

df.groupby(df['DropOffBorough'])['total_amount'].agg(['median','min','max','sum'])
# Out:
#                  median    min     max        sum
# DropOffBorough
# Bronx            20.300   0.00  120.90   46333.37
# Brooklyn         19.200   0.00  426.00  163015.10
# EWR             141.525  80.25  181.74    2808.66
# Manhattan        17.350   0.00  201.00  731813.64
# Queens           16.800   0.00  491.00  359239.13
# Staten Island    31.550   4.25  110.25     667.50
# Unknown          15.600   0.00  200.00    8525.68

# %%
df[df['PickUpBorough'] == 'Manhattan']['PickUpZone'].value_counts(ascending=True).tail(10).plot(kind='barh', figsize=(10, 6), color='skyblue')
# Out:
# <Axes: ylabel='PickUpZone'>

# %%
df[df['PickUpBorough'] == 'Manhattan']['DropOffZone'].value_counts(ascending=True).tail(10).plot(kind='barh', figsize=(10, 6), color='skyblue')
# Out:
# <Axes: ylabel='DropOffZone'>

# %% [markdown]
# 1. East Harlem (North & South) is a major hub for both pickups and drop-offs, suggesting it's a core operational zone — possibly due to:
#
#     - High population density
#
#     - Limited public transportation
#
#     - High reliance on taxis/rideshare
#
# 2. Other key areas like Central Harlem, Morningside Heights, and the Upper East/West Sides show significant drop-off traffic, indicating diverse travel patterns.

# %%
# Create a cross-tabulation between Pickup Location (PULocationID) and Dropoff Location (DOLocationID)
cross_tab = pd.crosstab(df['PickUpBorough'], df['DropOffBorough'])

# Optionally, you can add margins to get row and column totals
cross_tab_with_totals = pd.crosstab(df['PickUpBorough'], df['DropOffBorough'], margins=True, margins_name='Total')

cross_tab_with_totals
# Out:
# DropOffBorough  Bronx  Brooklyn  EWR  Manhattan  Queens  Staten Island  \
# PickUpBorough
# Bronx             595        16    0        220      32              0
# Brooklyn           36      6156    7       1319     342              2
# EWR                 0         0    0          0       0              0
# Manhattan        1306       225    7      33838     739              3
# Queens             39       463    5        822   15453              1
# Staten Island       0         2    0          0       1              8
# Unknown             0         2    0          0       1              0
# Total            1976      6864   19      36199   16568             14
#
# DropOffBorough  Unknown  Total
# PickUpBorough
# Bronx                17    880
# Brooklyn             59   7921
# EWR                   1      1
# Manhattan            71  36189
# Queens              124  16907
# Staten Island         0     11
# Unknown             126    129
# Total               398  62038

# %%
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu', cbar=False, linewidths=0.5)
# Out:
# <Axes: xlabel='DropOffBorough', ylabel='PickUpBorough'>

# %% [markdown]
# - Intra-borough travel is the dominant pattern, especially within Manhattan, Queens, and Brooklyn.
#
# - Manhattan acts as the central hub, receiving the highest number of cross-borough trips.
#
# - Staten Island and EWR have minimal taxi trip activity in this dataset, possibly due to distance, transit alternatives, or data capture limitations.

# %% [markdown]
# # 6. Geographical Views
# ---

# %%
NycMap = gpd.read_file(r"C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\CAPSTONE MODUL 2\Data Web Nyc Tlc\taxi_zones\taxi_zones.shp")

# %%
NycMap
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
# ...

# %%
NycMap.plot(figsize=(10, 8), edgecolor='black', cmap='viridis')
plt.title('NYC Taxi Zones Map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
df.groupby(df['PickUpZone']).count()
# Out:
#                          vendor  lpep_pickup_datetime  lpep_dropoff_datetime  \
# PickUpZone
# Allerton/Pelham Gardens       6                     6                      6
# Astoria                    1813                  1813                   1813
# Auburndale                   11                    11                     11
# Baisley Park                 24                    24                     24
# Bath Beach                    6                     6                      6
# ...                         ...                   ...                    ...
# Woodlawn/Wakefield            5                     5                      5
# Woodside                   1295                  1295                   1295
# World Trade Center            1                     1                      1
# Yorkville East                8                     8                      8
# Yorkville West               71                    71                     71
#
# ...

# %%
df_PU_zone_count = pd.DataFrame(df.groupby(df['PickUpZone']).count()['lpep_pickup_datetime'])

# %%
df_PU_zone_count.reset_index(inplace=True)

# %%
df_PU_zone_count
# Out:
#                   PickUpZone  lpep_pickup_datetime
# 0    Allerton/Pelham Gardens                     6
# 1                    Astoria                  1813
# 2                 Auburndale                    11
# 3               Baisley Park                    24
# 4                 Bath Beach                     6
# ..                       ...                   ...
# 214       Woodlawn/Wakefield                     5
# 215                 Woodside                  1295
# 216       World Trade Center                     1
# 217           Yorkville East                     8
# 218           Yorkville West                    71
#
# [219 rows x 2 columns]

# %%
df_PU_zone_map = df_PU_zone_count.merge(NycMap[['geometry']], left_on=df_PU_zone_count['PickUpZone'], right_on=NycMap['zone'], how='inner')

# %%
df_PU_zone_map.drop(columns=['key_0'], inplace=True)

# %%
df_PU_zone_map['trip_counts']= df_PU_zone_map['lpep_pickup_datetime']

# %%
df_PU_zone_map.drop(columns='lpep_pickup_datetime', inplace=True)

# %%
df_PU_zone_map
# Out:
#                   PickUpZone  \
# 0    Allerton/Pelham Gardens
# 1                    Astoria
# 2                 Auburndale
# 3               Baisley Park
# 4                 Bath Beach
# ..                       ...
# 214       Woodlawn/Wakefield
# 215                 Woodside
# 216       World Trade Center
# 217           Yorkville East
# 218           Yorkville West
#
#                                               geometry  trip_counts
# 0    POLYGON ((1026308.77 256767.698, 1026495.593 2...            6
# 1    POLYGON ((1010804.218 218919.641, 1011049.165 ...         1813
# 2    POLYGON ((1043803.993 216615.925, 1043849.708 ...           11
# 3    POLYGON ((1044355.072 190734.321, 1044612.122 ...           24
# 4    POLYGON ((983945.076 158978.174, 984160.158 15...            6
# ..                                                 ...          ...
# 214  POLYGON ((1025414.782 270986.139, 1025138.624 ...            5
# ...

# %%
print(type(df_PU_zone_map))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Convert to GeoDataFrame
df_PU_zone_map = gpd.GeoDataFrame(df_PU_zone_map, geometry='geometry', crs="EPSG:2263")  # atau CRS yang sesuai

# %%
# Plotting the map with trip counts

df_PU_zone_map.plot(
    column='trip_counts',
    cmap='coolwarm',
    legend=True,
    edgecolor='black',
    linewidth=0.3,
    figsize=(12, 8)
)

plt.title('Trips over PickUp Zone')
plt.axis('off')
plt.show()

# %% [markdown]
# - East Harlem North is the epicenter of pickup activity in NYC for this dataset.
#
# - Manhattan overall — especially upper and central regions — dominates ride-hailing demand.
#
# - Outer boroughs show far lower pickup volumes, suggesting potential service gaps or different transportation habits.

# %% [markdown]
# ## 7. Conclusion

# %% [markdown]
# ### 1. Trip Volume & Patterns
# - Most trips are solo rides (1 passenger), highlighting a preference or necessity for individual travel.
#
# - Trips peak in the afternoon (3–6 PM) across all days, especially Tuesday to Friday.
#
# - Weekdays have higher trip volume and revenue than weekends.
#
# - East Harlem North and South are the top pickup zones, showing extreme concentration of ride demand.
#
# - Most drop-offs occur within the same borough as the pickup, especially within Manhattan, Queens, and Brooklyn.
#
# ### 2. Revenue Insights
# - Manhattan generates the highest revenue by far (~$730K), followed by Queens and Brooklyn.
#
# - Credit card payments dominate in revenue, thanks to their direct link to tipping and fare tracking.
#
# - Shorter trips tend to receive higher tip percentages, while longer trips receive lower proportional tips.
#
# ### 3. Payment Behavior
# - Credit card is the most used and most profitable payment type, heavily linked to tipping behavior.
#
# - Cash trips are still significant but rarely include tips.
#
# - Digital tipping (via credit card) peaks at preset percentages like 20–25%.
#
# ### 4. Geographic Distribution
# - Manhattan is the operational hub — central for both trip volume and revenue.
#
# - East Harlem is the highest pickup zone, suggesting concentrated demand in specific neighborhoods.
#
# - Staten Island and EWR are rarely used zones, suggesting limited coverage or demand.

# %% [markdown]
# ### Identified Problems
# - High concentration of demand in a few zones → operational inefficiency in other areas.
#
# - Low tipping rates for longer trips and cash users → reduced driver incentive.
#
# - Limited activity in boroughs like Staten Island and the Bronx → potential market gaps.
#
# - Heavy dependence on credit card tipping → low tips for cash trips and missed revenue.
#
# - Disproportionate solo rides → low vehicle occupancy reduces efficiency.
#
# ### Problem-Solving Strategies
# 1. Expand Demand to Other Boroughs
#     - Incentivize rides in low-demand zones (e.g., Staten Island, EWR) via fare discounts or driver bonuses.
#
#     - Partner with local businesses or services in those areas to increase trip demand.
#
# 2. Promote Digital Payments
#     - Offer small fare discounts for credit card use or app-based payments to increase tip rates.
#
#     - Install tipping prompts or fixed tip suggestions for cash rides using printed QR codes or apps.
#
# 3. Optimize Fleet Allocation
#     - Use dynamic dispatching to balance supply between East Harlem and underserved zones.
#
#     - Apply predictive modeling to anticipate demand spikes (e.g., after school/work hours) and shift fleet accordingly.
#
# 4. Promote Shared Rides / Group Options
#     - Encourage use of group ride options during peak hours through lower fares or faster pickup guarantees.
#
#     - Educate users about environmental and cost benefits of shared rides.
#
# 5. Monitor & Tweak Tip Models
#     - Analyze tipping behavior based on fare, time, and customer segment.
#
#     - Experiment with tiered tip suggestions (e.g., 15% for short, 10% for long trips).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62302 entries, 0 to 62301
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor                 62302 non-null  object
#  1   lpep_pickup_datetime   62302 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62302 non-null  datetime64[ns]
#  3   record_flag            62302 non-null  object
#  4   rate_code              62302 non-null  object
#  5   PULocationID           62302 non-null  int64
#  6   PickUpBorough          62238 non-null  object
#  7   PickUpZone             62173 non-null  object
#  8   DOLocationID           62302 non-null  int64
#  9   DropOffBorough         62082 non-null  object
#  10  DropOffZone            61899 non-null  object
#  11  passenger_count        62302 non-null  Int64
#  12  trip_distance          62302 non-null  float64
#  13  fare_amount            62302 non-null  float64
# ...

# %%
df.to_csv('output/cleaned_taxi_data.csv', index=False)

# %%
df.to_excel('output/cleaned_taxi_data.xlsx', index=False)

# %%
mn.bar(df, figsize=(15, 5), fontsize=12)
# Out:
# <Axes: >
